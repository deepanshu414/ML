# %%
import matplotlib.pyplot as plt
from matplotlib import style

# %%
style.use("ggplot")
plt.grid("k-")

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.subplot(2,2,2)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.savefig("dim")
